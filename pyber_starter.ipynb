# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
cd = pd.read_csv(city_data_to_load)
rd = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset


cdrd = pd.merge(cd, rd, how='inner', on='city', sort=False)

# Display the data table for preview
cdrd.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
AvgFare1 = round(cdrd.groupby(['city']).mean(),2)
AvgFare = AvgFare1.drop(['driver_count', 'ride_id'], axis=1)

TotalRides1 = cdrd.groupby(['city']).count()
TotalRides = TotalRides1.drop(['driver_count', 'type', 'date', 'fare'], axis=1)
DriversPerCity = cd.drop(['type'], axis=1)
CityType1 = cd.groupby(['type']).count()
CityTypeLegend = CityType1.drop(['city', 'driver_count'], axis=1)
CityType = cd.drop(['driver_count'], axis=1)

AvgFareg = pd.merge(AvgFare, CityType, how='inner', on='city',sort=False)
AvgFareF = AvgFareg.groupby(['type']).mean()
TotalRidesg = pd.merge(TotalRides, CityType, how='inner', on='city',sort=False)
TotalRidesF1 = TotalRidesg.groupby(['type']).count()
TotalRidesF = TotalRidesF1.drop(['ride_id'], axis=1)
# Build the scatter plots for each city types

plt.scatter(TotalRidesF, AvgFareF)
# Incorporate the other graph properties
w = 50
h = 50
d = 50
# Create a legend
#TotalRidesF.head()
# Incorporate a text label regarding circle size

# Save Figure

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
percentages = plt.pie(TotalRidesF, labels=['Rural', 'Suburban','Urban'],autopct='%.1f%%')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
percentages = plt.pie(TotalRidesF, labels=['Rural', 'Suburban','Urban'],autopct='%.1f%%')
# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
totdrivers = cd.groupby(['type']).sum()
# Build Pie Charts
totdriverspie = plt.pie(totdrivers , labels=['Rural',  'Suburban','Urban'],autopct='%.1f%%')
# Save Figure

# %%
# Show Figure
plt.show()
